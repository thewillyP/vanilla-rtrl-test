# %%
import sys, os, pickle
sys.path.append('/home/om2382/vanilla-rtrl/')
from cluster import *
from continual_learning import *
from core import *
from dynamics import *
from functions import *
from gen_data import *
from learning_algorithms import *
from optimizers import *
from plotting import *
from torch_tools import *
from wrappers import *
import matplotlib.pyplot as plt
import torch
from torch.optim.lr_scheduler import ExponentialLR

# %%
### --- SET UP ALL CONFIGS --- ###
from itertools import product
n_seeds = 50
macro_configs = config_generator()
micro_configs = tuple(product(macro_configs, list(range(n_seeds))))

# %%
# !ls saved_runs/
# Out:
# BPTT_50_examples_ctx0_seed=0		BPTT_examples_ctx0_seed=5
# BPTT_50_examples_ctx0_seed=1		BPTT_examples_ctx0_seed=6
# BPTT_50_examples_ctx0_seed=10		BPTT_examples_ctx0_seed=7
# BPTT_50_examples_ctx0_seed=11		BPTT_examples_ctx0_seed=8
# BPTT_50_examples_ctx0_seed=12		BPTT_examples_ctx0_seed=9
# BPTT_50_examples_ctx0_seed=13		RFLO_50_examples_ctx0_seed=0
# BPTT_50_examples_ctx0_seed=14		RFLO_50_examples_ctx0_seed=1
# BPTT_50_examples_ctx0_seed=15		RFLO_50_examples_ctx0_seed=10
# BPTT_50_examples_ctx0_seed=16		RFLO_50_examples_ctx0_seed=11
# BPTT_50_examples_ctx0_seed=17		RFLO_50_examples_ctx0_seed=12
# BPTT_50_examples_ctx0_seed=18		RFLO_50_examples_ctx0_seed=13
# BPTT_50_examples_ctx0_seed=19		RFLO_50_examples_ctx0_seed=14
# BPTT_50_examples_ctx0_seed=2		RFLO_50_examples_ctx0_seed=15
# BPTT_50_examples_ctx0_seed=20		RFLO_50_examples_ctx0_seed=16
# BPTT_50_examples_ctx0_seed=21		RFLO_50_examples_ctx0_seed=17
# BPTT_50_examples_ctx0_seed=22		RFLO_50_examples_ctx0_seed=18
# BPTT_50_examples_ctx0_seed=23		RFLO_50_examples_ctx0_seed=19
# BPTT_50_examples_ctx0_seed=24		RFLO_50_examples_ctx0_seed=2
# BPTT_50_examples_ctx0_seed=25		RFLO_50_examples_ctx0_seed=20
# BPTT_50_examples_ctx0_seed=26		RFLO_50_examples_ctx0_seed=21
# BPTT_50_examples_ctx0_seed=27		RFLO_50_examples_ctx0_seed=22
# BPTT_50_examples_ctx0_seed=28		RFLO_50_examples_ctx0_seed=23
# BPTT_50_examples_ctx0_seed=29		RFLO_50_examples_ctx0_seed=24
# BPTT_50_examples_ctx0_seed=3		RFLO_50_examples_ctx0_seed=25
# BPTT_50_examples_ctx0_seed=30		RFLO_50_examples_ctx0_seed=26
# BPTT_50_examples_ctx0_seed=31		RFLO_50_examples_ctx0_seed=27
# BPTT_50_examples_ctx0_seed=32		RFLO_50_examples_ctx0_seed=28
# BPTT_50_examples_ctx0_seed=33		RFLO_50_examples_ctx0_seed=29
# BPTT_50_examples_ctx0_seed=34		RFLO_50_examples_ctx0_seed=3
# BPTT_50_examples_ctx0_seed=35		RFLO_50_examples_ctx0_seed=30
# BPTT_50_examples_ctx0_seed=36		RFLO_50_examples_ctx0_seed=31
# BPTT_50_examples_ctx0_seed=37		RFLO_50_examples_ctx0_seed=32
# BPTT_50_examples_ctx0_seed=38		RFLO_50_examples_ctx0_seed=33
# BPTT_50_examples_ctx0_seed=39		RFLO_50_examples_ctx0_seed=34
# BPTT_50_examples_ctx0_seed=4		RFLO_50_examples_ctx0_seed=35
# BPTT_50_examples_ctx0_seed=40		RFLO_50_examples_ctx0_seed=36
# BPTT_50_examples_ctx0_seed=41		RFLO_50_examples_ctx0_seed=37
# BPTT_50_examples_ctx0_seed=42		RFLO_50_examples_ctx0_seed=38
# BPTT_50_examples_ctx0_seed=43		RFLO_50_examples_ctx0_seed=39
# BPTT_50_examples_ctx0_seed=44		RFLO_50_examples_ctx0_seed=4
# BPTT_50_examples_ctx0_seed=45		RFLO_50_examples_ctx0_seed=40
# BPTT_50_examples_ctx0_seed=46		RFLO_50_examples_ctx0_seed=41
# BPTT_50_examples_ctx0_seed=47		RFLO_50_examples_ctx0_seed=42
# BPTT_50_examples_ctx0_seed=48		RFLO_50_examples_ctx0_seed=43
# BPTT_50_examples_ctx0_seed=49		RFLO_50_examples_ctx0_seed=44
# BPTT_50_examples_ctx0_seed=5		RFLO_50_examples_ctx0_seed=45
# BPTT_50_examples_ctx0_seed=6		RFLO_50_examples_ctx0_seed=46
# BPTT_50_examples_ctx0_seed=7		RFLO_50_examples_ctx0_seed=47
# BPTT_50_examples_ctx0_seed=8		RFLO_50_examples_ctx0_seed=48
# BPTT_50_examples_ctx0_seed=9		RFLO_50_examples_ctx0_seed=49
# BPTT_CDM_50_examples_ctx0_seed=0	RFLO_50_examples_ctx0_seed=5
# BPTT_CDM_50_examples_ctx0_seed=1	RFLO_50_examples_ctx0_seed=6
# BPTT_CDM_50_examples_ctx0_seed=10	RFLO_50_examples_ctx0_seed=7
# BPTT_CDM_50_examples_ctx0_seed=11	RFLO_50_examples_ctx0_seed=8
# BPTT_CDM_50_examples_ctx0_seed=12	RFLO_50_examples_ctx0_seed=9
# BPTT_CDM_50_examples_ctx0_seed=13	RFLO_CDM_50_examples_ctx0_seed=0
# BPTT_CDM_50_examples_ctx0_seed=14	RFLO_CDM_50_examples_ctx0_seed=1
# BPTT_CDM_50_examples_ctx0_seed=15	RFLO_CDM_50_examples_ctx0_seed=10
# BPTT_CDM_50_examples_ctx0_seed=16	RFLO_CDM_50_examples_ctx0_seed=11
# BPTT_CDM_50_examples_ctx0_seed=17	RFLO_CDM_50_examples_ctx0_seed=12
# BPTT_CDM_50_examples_ctx0_seed=18	RFLO_CDM_50_examples_ctx0_seed=13
# BPTT_CDM_50_examples_ctx0_seed=19	RFLO_CDM_50_examples_ctx0_seed=14
# BPTT_CDM_50_examples_ctx0_seed=2	RFLO_CDM_50_examples_ctx0_seed=15
# BPTT_CDM_50_examples_ctx0_seed=20	RFLO_CDM_50_examples_ctx0_seed=16
# BPTT_CDM_50_examples_ctx0_seed=21	RFLO_CDM_50_examples_ctx0_seed=17
# BPTT_CDM_50_examples_ctx0_seed=22	RFLO_CDM_50_examples_ctx0_seed=18
# BPTT_CDM_50_examples_ctx0_seed=23	RFLO_CDM_50_examples_ctx0_seed=19
# BPTT_CDM_50_examples_ctx0_seed=24	RFLO_CDM_50_examples_ctx0_seed=2
# BPTT_CDM_50_examples_ctx0_seed=25	RFLO_CDM_50_examples_ctx0_seed=20
# BPTT_CDM_50_examples_ctx0_seed=26	RFLO_CDM_50_examples_ctx0_seed=21
# BPTT_CDM_50_examples_ctx0_seed=27	RFLO_CDM_50_examples_ctx0_seed=22
# BPTT_CDM_50_examples_ctx0_seed=28	RFLO_CDM_50_examples_ctx0_seed=23
# BPTT_CDM_50_examples_ctx0_seed=29	RFLO_CDM_50_examples_ctx0_seed=24
# BPTT_CDM_50_examples_ctx0_seed=3	RFLO_CDM_50_examples_ctx0_seed=25
# BPTT_CDM_50_examples_ctx0_seed=30	RFLO_CDM_50_examples_ctx0_seed=26
# BPTT_CDM_50_examples_ctx0_seed=31	RFLO_CDM_50_examples_ctx0_seed=27
# BPTT_CDM_50_examples_ctx0_seed=32	RFLO_CDM_50_examples_ctx0_seed=28
# BPTT_CDM_50_examples_ctx0_seed=33	RFLO_CDM_50_examples_ctx0_seed=29
# BPTT_CDM_50_examples_ctx0_seed=34	RFLO_CDM_50_examples_ctx0_seed=3
# BPTT_CDM_50_examples_ctx0_seed=35	RFLO_CDM_50_examples_ctx0_seed=30
# BPTT_CDM_50_examples_ctx0_seed=36	RFLO_CDM_50_examples_ctx0_seed=31
# BPTT_CDM_50_examples_ctx0_seed=37	RFLO_CDM_50_examples_ctx0_seed=32
# BPTT_CDM_50_examples_ctx0_seed=38	RFLO_CDM_50_examples_ctx0_seed=33
# BPTT_CDM_50_examples_ctx0_seed=39	RFLO_CDM_50_examples_ctx0_seed=34
# BPTT_CDM_50_examples_ctx0_seed=4	RFLO_CDM_50_examples_ctx0_seed=35
# BPTT_CDM_50_examples_ctx0_seed=40	RFLO_CDM_50_examples_ctx0_seed=36
# BPTT_CDM_50_examples_ctx0_seed=41	RFLO_CDM_50_examples_ctx0_seed=37
# BPTT_CDM_50_examples_ctx0_seed=42	RFLO_CDM_50_examples_ctx0_seed=38
# BPTT_CDM_50_examples_ctx0_seed=43	RFLO_CDM_50_examples_ctx0_seed=39
# BPTT_CDM_50_examples_ctx0_seed=44	RFLO_CDM_50_examples_ctx0_seed=4
# BPTT_CDM_50_examples_ctx0_seed=45	RFLO_CDM_50_examples_ctx0_seed=40
# BPTT_CDM_50_examples_ctx0_seed=46	RFLO_CDM_50_examples_ctx0_seed=41
# BPTT_CDM_50_examples_ctx0_seed=47	RFLO_CDM_50_examples_ctx0_seed=42
# BPTT_CDM_50_examples_ctx0_seed=48	RFLO_CDM_50_examples_ctx0_seed=43
# BPTT_CDM_50_examples_ctx0_seed=49	RFLO_CDM_50_examples_ctx0_seed=44
# BPTT_CDM_50_examples_ctx0_seed=5	RFLO_CDM_50_examples_ctx0_seed=45
# BPTT_CDM_50_examples_ctx0_seed=6	RFLO_CDM_50_examples_ctx0_seed=46
# BPTT_CDM_50_examples_ctx0_seed=7	RFLO_CDM_50_examples_ctx0_seed=47
# BPTT_CDM_50_examples_ctx0_seed=8	RFLO_CDM_50_examples_ctx0_seed=48
# BPTT_CDM_50_examples_ctx0_seed=9	RFLO_CDM_50_examples_ctx0_seed=49
# BPTT_CDM_b200_50_examples_ctx0_seed=0	RFLO_CDM_50_examples_ctx0_seed=5
# BPTT_CDM_b200_50_examples_ctx0_seed=1	RFLO_CDM_50_examples_ctx0_seed=6
# BPTT_CDM_b200_50_examples_ctx0_seed=10	RFLO_CDM_50_examples_ctx0_seed=7
# BPTT_CDM_b200_50_examples_ctx0_seed=11	RFLO_CDM_50_examples_ctx0_seed=8
# BPTT_CDM_b200_50_examples_ctx0_seed=12	RFLO_CDM_50_examples_ctx0_seed=9
# BPTT_CDM_b200_50_examples_ctx0_seed=13	RFLO_CDM_b200_50_examples_ctx0_seed=0
# BPTT_CDM_b200_50_examples_ctx0_seed=14	RFLO_CDM_b200_50_examples_ctx0_seed=1
# BPTT_CDM_b200_50_examples_ctx0_seed=15	RFLO_CDM_b200_50_examples_ctx0_seed=10
# BPTT_CDM_b200_50_examples_ctx0_seed=16	RFLO_CDM_b200_50_examples_ctx0_seed=11
# BPTT_CDM_b200_50_examples_ctx0_seed=17	RFLO_CDM_b200_50_examples_ctx0_seed=12
# BPTT_CDM_b200_50_examples_ctx0_seed=18	RFLO_CDM_b200_50_examples_ctx0_seed=13
# BPTT_CDM_b200_50_examples_ctx0_seed=19	RFLO_CDM_b200_50_examples_ctx0_seed=14
# BPTT_CDM_b200_50_examples_ctx0_seed=2	RFLO_CDM_b200_50_examples_ctx0_seed=15
# BPTT_CDM_b200_50_examples_ctx0_seed=20	RFLO_CDM_b200_50_examples_ctx0_seed=16
# BPTT_CDM_b200_50_examples_ctx0_seed=21	RFLO_CDM_b200_50_examples_ctx0_seed=17
# BPTT_CDM_b200_50_examples_ctx0_seed=22	RFLO_CDM_b200_50_examples_ctx0_seed=18
# BPTT_CDM_b200_50_examples_ctx0_seed=23	RFLO_CDM_b200_50_examples_ctx0_seed=19
# BPTT_CDM_b200_50_examples_ctx0_seed=24	RFLO_CDM_b200_50_examples_ctx0_seed=2
# BPTT_CDM_b200_50_examples_ctx0_seed=25	RFLO_CDM_b200_50_examples_ctx0_seed=20
# BPTT_CDM_b200_50_examples_ctx0_seed=26	RFLO_CDM_b200_50_examples_ctx0_seed=21
# BPTT_CDM_b200_50_examples_ctx0_seed=27	RFLO_CDM_b200_50_examples_ctx0_seed=22
# BPTT_CDM_b200_50_examples_ctx0_seed=28	RFLO_CDM_b200_50_examples_ctx0_seed=23
# BPTT_CDM_b200_50_examples_ctx0_seed=29	RFLO_CDM_b200_50_examples_ctx0_seed=24
# BPTT_CDM_b200_50_examples_ctx0_seed=3	RFLO_CDM_b200_50_examples_ctx0_seed=25
# BPTT_CDM_b200_50_examples_ctx0_seed=30	RFLO_CDM_b200_50_examples_ctx0_seed=26
# BPTT_CDM_b200_50_examples_ctx0_seed=31	RFLO_CDM_b200_50_examples_ctx0_seed=27
# BPTT_CDM_b200_50_examples_ctx0_seed=32	RFLO_CDM_b200_50_examples_ctx0_seed=28
# BPTT_CDM_b200_50_examples_ctx0_seed=33	RFLO_CDM_b200_50_examples_ctx0_seed=29
# BPTT_CDM_b200_50_examples_ctx0_seed=34	RFLO_CDM_b200_50_examples_ctx0_seed=3
# BPTT_CDM_b200_50_examples_ctx0_seed=35	RFLO_CDM_b200_50_examples_ctx0_seed=30
# BPTT_CDM_b200_50_examples_ctx0_seed=36	RFLO_CDM_b200_50_examples_ctx0_seed=31
# BPTT_CDM_b200_50_examples_ctx0_seed=37	RFLO_CDM_b200_50_examples_ctx0_seed=32
# BPTT_CDM_b200_50_examples_ctx0_seed=38	RFLO_CDM_b200_50_examples_ctx0_seed=33
# BPTT_CDM_b200_50_examples_ctx0_seed=39	RFLO_CDM_b200_50_examples_ctx0_seed=34
# BPTT_CDM_b200_50_examples_ctx0_seed=4	RFLO_CDM_b200_50_examples_ctx0_seed=35
# BPTT_CDM_b200_50_examples_ctx0_seed=40	RFLO_CDM_b200_50_examples_ctx0_seed=36
# BPTT_CDM_b200_50_examples_ctx0_seed=41	RFLO_CDM_b200_50_examples_ctx0_seed=37
# BPTT_CDM_b200_50_examples_ctx0_seed=42	RFLO_CDM_b200_50_examples_ctx0_seed=38
# BPTT_CDM_b200_50_examples_ctx0_seed=43	RFLO_CDM_b200_50_examples_ctx0_seed=39
# BPTT_CDM_b200_50_examples_ctx0_seed=44	RFLO_CDM_b200_50_examples_ctx0_seed=4
# BPTT_CDM_b200_50_examples_ctx0_seed=45	RFLO_CDM_b200_50_examples_ctx0_seed=40
# BPTT_CDM_b200_50_examples_ctx0_seed=46	RFLO_CDM_b200_50_examples_ctx0_seed=41
# BPTT_CDM_b200_50_examples_ctx0_seed=47	RFLO_CDM_b200_50_examples_ctx0_seed=42
# BPTT_CDM_b200_50_examples_ctx0_seed=48	RFLO_CDM_b200_50_examples_ctx0_seed=43
# BPTT_CDM_b200_50_examples_ctx0_seed=49	RFLO_CDM_b200_50_examples_ctx0_seed=44
# BPTT_CDM_b200_50_examples_ctx0_seed=5	RFLO_CDM_b200_50_examples_ctx0_seed=45
# BPTT_CDM_b200_50_examples_ctx0_seed=6	RFLO_CDM_b200_50_examples_ctx0_seed=46
# BPTT_CDM_b200_50_examples_ctx0_seed=7	RFLO_CDM_b200_50_examples_ctx0_seed=47
# BPTT_CDM_b200_50_examples_ctx0_seed=8	RFLO_CDM_b200_50_examples_ctx0_seed=48
# BPTT_CDM_b200_50_examples_ctx0_seed=9	RFLO_CDM_b200_50_examples_ctx0_seed=49
# BPTT_CDM_lr01_50_examples_ctx0_seed=0	RFLO_CDM_b200_50_examples_ctx0_seed=5
# BPTT_CDM_lr01_50_examples_ctx0_seed=1	RFLO_CDM_b200_50_examples_ctx0_seed=6
# BPTT_CDM_lr01_50_examples_ctx0_seed=10	RFLO_CDM_b200_50_examples_ctx0_seed=7
# BPTT_CDM_lr01_50_examples_ctx0_seed=11	RFLO_CDM_b200_50_examples_ctx0_seed=8
# BPTT_CDM_lr01_50_examples_ctx0_seed=12	RFLO_CDM_b200_50_examples_ctx0_seed=9
# BPTT_CDM_lr01_50_examples_ctx0_seed=13	RFLO_CDM_lr01_50_examples_ctx0_seed=0
# BPTT_CDM_lr01_50_examples_ctx0_seed=14	RFLO_CDM_lr01_50_examples_ctx0_seed=1
# BPTT_CDM_lr01_50_examples_ctx0_seed=15	RFLO_CDM_lr01_50_examples_ctx0_seed=10
# BPTT_CDM_lr01_50_examples_ctx0_seed=16	RFLO_CDM_lr01_50_examples_ctx0_seed=11
# BPTT_CDM_lr01_50_examples_ctx0_seed=17	RFLO_CDM_lr01_50_examples_ctx0_seed=12
# BPTT_CDM_lr01_50_examples_ctx0_seed=18	RFLO_CDM_lr01_50_examples_ctx0_seed=13
# BPTT_CDM_lr01_50_examples_ctx0_seed=19	RFLO_CDM_lr01_50_examples_ctx0_seed=14
# BPTT_CDM_lr01_50_examples_ctx0_seed=2	RFLO_CDM_lr01_50_examples_ctx0_seed=15
# BPTT_CDM_lr01_50_examples_ctx0_seed=20	RFLO_CDM_lr01_50_examples_ctx0_seed=16
# BPTT_CDM_lr01_50_examples_ctx0_seed=21	RFLO_CDM_lr01_50_examples_ctx0_seed=17
# BPTT_CDM_lr01_50_examples_ctx0_seed=22	RFLO_CDM_lr01_50_examples_ctx0_seed=18
# BPTT_CDM_lr01_50_examples_ctx0_seed=23	RFLO_CDM_lr01_50_examples_ctx0_seed=19
# BPTT_CDM_lr01_50_examples_ctx0_seed=24	RFLO_CDM_lr01_50_examples_ctx0_seed=2
# BPTT_CDM_lr01_50_examples_ctx0_seed=25	RFLO_CDM_lr01_50_examples_ctx0_seed=20
# BPTT_CDM_lr01_50_examples_ctx0_seed=26	RFLO_CDM_lr01_50_examples_ctx0_seed=21
# BPTT_CDM_lr01_50_examples_ctx0_seed=27	RFLO_CDM_lr01_50_examples_ctx0_seed=22
# BPTT_CDM_lr01_50_examples_ctx0_seed=28	RFLO_CDM_lr01_50_examples_ctx0_seed=23
# BPTT_CDM_lr01_50_examples_ctx0_seed=29	RFLO_CDM_lr01_50_examples_ctx0_seed=24
# BPTT_CDM_lr01_50_examples_ctx0_seed=3	RFLO_CDM_lr01_50_examples_ctx0_seed=25
# BPTT_CDM_lr01_50_examples_ctx0_seed=30	RFLO_CDM_lr01_50_examples_ctx0_seed=26
# BPTT_CDM_lr01_50_examples_ctx0_seed=31	RFLO_CDM_lr01_50_examples_ctx0_seed=27
# BPTT_CDM_lr01_50_examples_ctx0_seed=32	RFLO_CDM_lr01_50_examples_ctx0_seed=28
# BPTT_CDM_lr01_50_examples_ctx0_seed=33	RFLO_CDM_lr01_50_examples_ctx0_seed=29
# BPTT_CDM_lr01_50_examples_ctx0_seed=34	RFLO_CDM_lr01_50_examples_ctx0_seed=3
# BPTT_CDM_lr01_50_examples_ctx0_seed=35	RFLO_CDM_lr01_50_examples_ctx0_seed=30
# BPTT_CDM_lr01_50_examples_ctx0_seed=36	RFLO_CDM_lr01_50_examples_ctx0_seed=31
# BPTT_CDM_lr01_50_examples_ctx0_seed=37	RFLO_CDM_lr01_50_examples_ctx0_seed=32
# BPTT_CDM_lr01_50_examples_ctx0_seed=38	RFLO_CDM_lr01_50_examples_ctx0_seed=33
# BPTT_CDM_lr01_50_examples_ctx0_seed=39	RFLO_CDM_lr01_50_examples_ctx0_seed=34
# BPTT_CDM_lr01_50_examples_ctx0_seed=4	RFLO_CDM_lr01_50_examples_ctx0_seed=35
# BPTT_CDM_lr01_50_examples_ctx0_seed=40	RFLO_CDM_lr01_50_examples_ctx0_seed=36
# BPTT_CDM_lr01_50_examples_ctx0_seed=41	RFLO_CDM_lr01_50_examples_ctx0_seed=37
# BPTT_CDM_lr01_50_examples_ctx0_seed=42	RFLO_CDM_lr01_50_examples_ctx0_seed=38
# BPTT_CDM_lr01_50_examples_ctx0_seed=43	RFLO_CDM_lr01_50_examples_ctx0_seed=39
# BPTT_CDM_lr01_50_examples_ctx0_seed=44	RFLO_CDM_lr01_50_examples_ctx0_seed=4
# BPTT_CDM_lr01_50_examples_ctx0_seed=45	RFLO_CDM_lr01_50_examples_ctx0_seed=40
# BPTT_CDM_lr01_50_examples_ctx0_seed=46	RFLO_CDM_lr01_50_examples_ctx0_seed=41
# BPTT_CDM_lr01_50_examples_ctx0_seed=47	RFLO_CDM_lr01_50_examples_ctx0_seed=42
# BPTT_CDM_lr01_50_examples_ctx0_seed=48	RFLO_CDM_lr01_50_examples_ctx0_seed=43
# BPTT_CDM_lr01_50_examples_ctx0_seed=49	RFLO_CDM_lr01_50_examples_ctx0_seed=44
# BPTT_CDM_lr01_50_examples_ctx0_seed=5	RFLO_CDM_lr01_50_examples_ctx0_seed=45
# BPTT_CDM_lr01_50_examples_ctx0_seed=6	RFLO_CDM_lr01_50_examples_ctx0_seed=46
# BPTT_CDM_lr01_50_examples_ctx0_seed=7	RFLO_CDM_lr01_50_examples_ctx0_seed=47
# BPTT_CDM_lr01_50_examples_ctx0_seed=8	RFLO_CDM_lr01_50_examples_ctx0_seed=48
# BPTT_CDM_lr01_50_examples_ctx0_seed=9	RFLO_CDM_lr01_50_examples_ctx0_seed=49
# BPTT_examples_ctx0_seed=0		RFLO_CDM_lr01_50_examples_ctx0_seed=5
# BPTT_examples_ctx0_seed=1		RFLO_CDM_lr01_50_examples_ctx0_seed=6
# BPTT_examples_ctx0_seed=2		RFLO_CDM_lr01_50_examples_ctx0_seed=7
# BPTT_examples_ctx0_seed=3		RFLO_CDM_lr01_50_examples_ctx0_seed=8
# BPTT_examples_ctx0_seed=4		RFLO_CDM_lr01_50_examples_ctx0_seed=9

# %%
root_name = 'RFLO_CDM_b200_50_examples_ctx0'
file_names = []
for params, i_seed in micro_configs:
    
    if i_seed <= 14:
        continue
    
    np.random.seed(i_seed)
    T_trial = 100
    task = Context_Dependent_Decision_Task(T_trial=T_trial, input_var=0.1, report_cue=True)
    N_train = 1000000
    N_test = 20000
    checkpoint_interval = 10
    data = task.gen_data(N_train, N_test, add_dummy_end_point=False)
    batched_data = add_batch_dimension_to_data(data, T_trial)

    ### --- initialize RNN paramters and RNN object --- ###
    n_in = task.n_in
    n_hidden = 32
    n_out = task.n_out

    W_in  = np.random.normal(0, np.sqrt(1/(n_in)), (n_hidden, n_in))
    W_rec = np.random.normal(0, np.sqrt(1/n_hidden), (n_hidden, n_hidden))
    W_out = np.random.normal(0, np.sqrt(1/(n_hidden)), (n_out, n_hidden))
    b_rec = np.zeros(n_hidden)
    b_out = np.zeros(n_out)

    alpha = 0.1

    rnn = Torch_RNN(W_in, W_rec, W_out, b_rec, b_out,
                    activation='tanh',
                    alpha=alpha)
    
    optimizer = torch.optim.Adam(rnn.parameters(), lr=0.001)
    scheduler = None
    checkpoints = train_torch_RNN_by_RFLO(rnn, optimizer, batched_data,
                                          batch_size=20, n_epochs=4,
                                          L2_reg=0.0001, verbose=True,
                                          checkpoint_interval=checkpoint_interval,
                                          scheduler=scheduler)
        
    sim = Empty_Simulation()
    sim.checkpoints = checkpoints
    indices = sorted([k for k in checkpoints.keys() if type(k) != str])
    sim.checkpoint_interval = indices[1] - indices[0]
    sim.total_time_steps = indices[-1] + sim.checkpoint_interval
    sim.rnn = checkpoints['final']['rnn']
    
    #fix context to context 0
    task.fixed_context = 0
    
    file_name = root_name + '_seed={}'.format(i_seed)
    for key in params.keys():
        file_name += '_{}={}'.format(key, str(params[key]).replace('.', ','))
        
    file_names.append(file_name)
    
    print('finish simulation: {}'.format(i_seed))
    for key in params.keys():
        print('{}:, {}, seed = {}'.format(key, params[key], i_seed))
    if np.isnan(rnn.W_rec.detach().numpy()[0, 0]):
        print('MISTAKES WERE MADE')
        break
    
    
    ### --- SAVE RUN --- ###
    with open(os.path.join('saved_runs/', file_name), 'wb') as f:
        saved_run = {'sim': sim, 'task': task}
        pickle.dump(saved_run, f)
# Out:
# Epoch 0, Batch 0
# Loss 37.83562088012695
# Epoch 0, Batch 50
# Loss 2.503274917602539
# Epoch 0, Batch 100
# Loss 2.1346757411956787
# Epoch 0, Batch 150
# Loss 2.1132307052612305
# Epoch 0, Batch 200
# Loss 2.1052756309509277
# Epoch 0, Batch 250
# Loss 2.068179130554199
# Epoch 0, Batch 300
# Loss 2.002070903778076
# Epoch 0, Batch 350
# Loss 1.9734102487564087
# Epoch 0, Batch 400
# Loss 1.9459611177444458
# Epoch 0, Batch 450
# Loss 1.94240403175354
# Epoch 1, Batch 0
# Loss 1.9611327648162842
# Epoch 1, Batch 50
# Loss 1.9216687679290771
# Epoch 1, Batch 100
# Loss 2.0016651153564453
# Epoch 1, Batch 150
# Loss 1.95534348487854
# Epoch 1, Batch 200
# Loss 1.961531400680542
# Epoch 1, Batch 250
# Loss 1.9575444459915161
# Epoch 1, Batch 300
# Loss 1.9112707376480103
# Epoch 1, Batch 350
# Loss 1.8988561630249023
# Epoch 1, Batch 400
# Loss 1.8917193412780762
# Epoch 1, Batch 450
# Loss 1.9190545082092285
# Epoch 2, Batch 0
# Loss 1.9349396228790283
# Epoch 2, Batch 50
# Loss 1.888861060142517
# Epoch 2, Batch 100
# Loss 1.9822558164596558
# Epoch 2, Batch 150
# Loss 1.9214144945144653
# Epoch 2, Batch 200
# Loss 1.9435033798217773
# Epoch 2, Batch 250
# Loss 1.9422519207000732
# Epoch 2, Batch 300
# Loss 1.9007447957992554
# Epoch 2, Batch 350
# Loss 1.8905982971191406
# Epoch 2, Batch 400
# Loss 1.8786152601242065
# Epoch 2, Batch 450
# Loss 1.9238272905349731
# Epoch 3, Batch 0
# Loss 1.9376782178878784
# Epoch 3, Batch 50
# Loss 1.8846735954284668
# Epoch 3, Batch 100
# Loss 1.989973545074463
# Epoch 3, Batch 150
# Loss 1.9174391031265259
# Epoch 3, Batch 200
# Loss 1.9372788667678833
# Epoch 3, Batch 250
# Loss 1.9319826364517212
# Epoch 3, Batch 300
# Loss 1.9007625579833984
# Epoch 3, Batch 350
# Loss 1.888045072555542
# Epoch 3, Batch 400
# Loss 1.8734362125396729
# Epoch 3, Batch 450
# Loss 1.9335392713546753
# finish simulation: 15
# Epoch 0, Batch 0
# Loss 22.896530151367188
# Epoch 0, Batch 50
# Loss 2.3157689571380615
# Epoch 0, Batch 100
# Loss 2.2272801399230957
# Epoch 0, Batch 150
# Loss 2.150977611541748
# Epoch 0, Batch 200
# Loss 2.1090378761291504
# Epoch 0, Batch 250
# Loss 2.0461881160736084
# Epoch 0, Batch 300
# Loss 2.0079808235168457
# Epoch 0, Batch 350
# Loss 2.0041754245758057
# Epoch 0, Batch 400
# Loss 1.926091194152832
# Epoch 0, Batch 450
# Loss 1.9711915254592896
# Epoch 1, Batch 0
# Loss 1.9788624048233032
# Epoch 1, Batch 50
# Loss 1.9517183303833008
# Epoch 1, Batch 100
# Loss 1.9610539674758911
# Epoch 1, Batch 150
# Loss 1.9675698280334473
# Epoch 1, Batch 200
# Loss 2.003145933151245
# Epoch 1, Batch 250
# Loss 1.9762177467346191
# Epoch 1, Batch 300
# Loss 1.9324942827224731
# Epoch 1, Batch 350
# Loss 1.964952826499939
# Epoch 1, Batch 400
# Loss 1.9124890565872192
# Epoch 1, Batch 450
# Loss 1.9579037427902222
# Epoch 2, Batch 0
# Loss 1.9526339769363403
# Epoch 2, Batch 50
# Loss 1.9449039697647095
# Epoch 2, Batch 100
# Loss 1.9389904737472534
# Epoch 2, Batch 150
# Loss 1.942759394645691
# Epoch 2, Batch 200
# Loss 1.975919246673584
# Epoch 2, Batch 250
# Loss 1.9665964841842651
# Epoch 2, Batch 300
# Loss 1.924574375152588
# Epoch 2, Batch 350
# Loss 1.9638385772705078
# Epoch 2, Batch 400
# Loss 1.9197986125946045
# Epoch 2, Batch 450
# Loss 1.95819091796875
# Epoch 3, Batch 0
# Loss 1.944584608078003
# Epoch 3, Batch 50
# Loss 1.9439464807510376
# Epoch 3, Batch 100
# Loss 1.9342089891433716
# Epoch 3, Batch 150
# Loss 1.9414193630218506
# Epoch 3, Batch 200
# Loss 1.9715207815170288
# Epoch 3, Batch 250
# Loss 1.9666539430618286
# Epoch 3, Batch 300
# Loss 1.928814172744751
# Epoch 3, Batch 350
# Loss 1.9654954671859741
# Epoch 3, Batch 400
# Loss 1.9247616529464722
# Epoch 3, Batch 450
# Loss 1.9560717344284058
# finish simulation: 16
# Epoch 0, Batch 0
# Loss 33.85727310180664
# Epoch 0, Batch 50
# Loss 2.621009349822998
# Epoch 0, Batch 100
# Loss 2.1708905696868896
# Epoch 0, Batch 150
# Loss 2.0791425704956055
# Epoch 0, Batch 200
# Loss 1.9695651531219482
# Epoch 0, Batch 250
# Loss 1.9733291864395142
# Epoch 0, Batch 300
# Loss 1.9691654443740845
# Epoch 0, Batch 350
# Loss 1.9784022569656372
# Epoch 0, Batch 400
# Loss 1.9652621746063232
# Epoch 0, Batch 450
# Loss 1.9524439573287964
# Epoch 1, Batch 0
# Loss 1.9655660390853882
# Epoch 1, Batch 50
# Loss 1.9668011665344238
# Epoch 1, Batch 100
# Loss 1.9407012462615967
# Epoch 1, Batch 150
# Loss 2.012876033782959
# Epoch 1, Batch 200
# Loss 1.9450832605361938
# Epoch 1, Batch 250
# Loss 1.9624240398406982
# Epoch 1, Batch 300
# Loss 1.9617981910705566
# Epoch 1, Batch 350
# Loss 1.9363375902175903
# Epoch 1, Batch 400
# Loss 1.9391487836837769
# Epoch 1, Batch 450
# Loss 1.9318732023239136
# Epoch 2, Batch 0
# Loss 1.9311922788619995
# Epoch 2, Batch 50
# Loss 1.9362587928771973
# Epoch 2, Batch 100
# Loss 1.928307056427002
# Epoch 2, Batch 150
# Loss 1.9909027814865112
# Epoch 2, Batch 200
# Loss 1.9378787279129028
# Epoch 2, Batch 250
# Loss 1.9552226066589355
# Epoch 2, Batch 300
# Loss 1.9479397535324097
# Epoch 2, Batch 350
# Loss 1.9163527488708496
# Epoch 2, Batch 400
# Loss 1.932763934135437
# Epoch 2, Batch 450
# Loss 1.930619716644287
# Epoch 3, Batch 0
# Loss 1.9070342779159546
# Epoch 3, Batch 50
# Loss 1.9372282028198242
# Epoch 3, Batch 100
# Loss 1.928832769393921
# Epoch 3, Batch 150
# Loss 1.9768157005310059
# Epoch 3, Batch 200
# Loss 1.9358272552490234
# Epoch 3, Batch 250
# Loss 1.943096399307251
# Epoch 3, Batch 300
# Loss 1.9569605588912964
# Epoch 3, Batch 350
# Loss 1.9218792915344238
# Epoch 3, Batch 400
# Loss 1.934023141860962
# Epoch 3, Batch 450
# Loss 1.9297547340393066
# finish simulation: 17
# Epoch 0, Batch 0
# Loss 75.43634796142578
# Epoch 0, Batch 50
# Loss 3.0387375354766846
# Epoch 0, Batch 100
# Loss 2.397847890853882
# Epoch 0, Batch 150
# Loss 2.1910290718078613
# Epoch 0, Batch 200
# Loss 2.177769899368286
# Epoch 0, Batch 250
# Loss 2.1463959217071533
# Epoch 0, Batch 300
# Loss 2.0575051307678223
# Epoch 0, Batch 350
# Loss 2.1045210361480713

# %%
### --- Full cross-checkpoint analysis --- ###
root_name = 'RFLO_CDM_b200_50_examples_ctx0'
cross_topological_analysis(root_name, FP_find_FPs=True,
                           FP_KE_criterion=0.00001, FP_N=1000, ppn=16, compare_n_comp_window=1,
                           FP_context=np.eye(5)[2],
                           n_checkpoints_per_job_=50,
                           n_compare_hours=24,
                           compare_n_comp_jobs=1000,
                           compare_only=False,
                           compare_aligned_graph=False,
                           compare_node_drift=False,
                           compare_node_diff=False,
                           test_N=2000, test_save_data=False, compare_CKA=False,
                           compare_PC1=False, compare_PC2=False, compare_PC3=False,
                           compare_cross_param_ordering=['seed'],
                           results_subdir='PNAS_Paper')
# Out:
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=0/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  301,590.67 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=1/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  904,772.00 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=10/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  904,772.00 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=11/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  301,590.67 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=12/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  904,772.00 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=13/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  301,590.67 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=14/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  904,772.00 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=15/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  301,590.67 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=16/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# ...
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  301,590.67 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=8/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  904,772.00 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/analyze_RFLO_CDM_b200_50_examples_ctx0_seed=9/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/
# vanilla-rtrl/.DS_Store
# vanilla-rtrl/.gitignore
# vanilla-rtrl/README.md
# vanilla-rtrl/__init__.py
# vanilla-rtrl/analyze_main.py
# vanilla-rtrl/compare_main.py
# vanilla-rtrl/cross_compare_main.py
# vanilla-rtrl/jupyter_notebook.py
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/.gitignore
# vanilla-rtrl/.idea/misc.xml
# vanilla-rtrl/.idea/modules.xml
# vanilla-rtrl/.idea/vanilla-rtrl.iml
# vanilla-rtrl/.idea/vcs.xml
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/.idea/codeStyles/
# vanilla-rtrl/.idea/codeStyles/codeStyleConfig.xml
# vanilla-rtrl/.idea/inspectionProfiles/
# vanilla-rtrl/.idea/inspectionProfiles/profiles_settings.xml
# vanilla-rtrl/.ipynb_checkpoints/
# vanilla-rtrl/.ipynb_checkpoints/main-checkpoint.ipynb
# vanilla-rtrl/cluster/
# vanilla-rtrl/cluster/__init__.py
# vanilla-rtrl/cluster/close_jupyter_notebook.py
# vanilla-rtrl/cluster/process_results.py
# vanilla-rtrl/cluster/start_jupyter_notebook.py
# vanilla-rtrl/cluster/submit_jobs.py
# vanilla-rtrl/cluster/sync_cluster.py
# vanilla-rtrl/continual_learning/
# vanilla-rtrl/continual_learning/Continual_Learning.py
# vanilla-rtrl/continual_learning/Duncker_Method.py
# vanilla-rtrl/continual_learning/Synaptic_Intelligence.py
# vanilla-rtrl/continual_learning/__init__.py
# vanilla-rtrl/core/
# vanilla-rtrl/core/RNN.py
# vanilla-rtrl/core/Simulation.py
# vanilla-rtrl/core/__init__.py
# vanilla-rtrl/dynamics/
# vanilla-rtrl/dynamics/Dynamics.py
# vanilla-rtrl/dynamics/VAE.py
# vanilla-rtrl/dynamics/__init__.py
# vanilla-rtrl/dynamics/checkpoint_funcs.py
# vanilla-rtrl/dynamics/distances.py
# vanilla-rtrl/dynamics/dynamics_utils.py
# vanilla-rtrl/dynamics/feature_space.py
# vanilla-rtrl/dynamics/metrics.py
# vanilla-rtrl/dynamics/topology.py
# vanilla-rtrl/dynamics/track_fixed_points.py
# vanilla-rtrl/functions/
# vanilla-rtrl/functions/Function.py
# vanilla-rtrl/functions/__init__.py
# vanilla-rtrl/functions/identity.py
# vanilla-rtrl/functions/mean_squared_error.py
# vanilla-rtrl/functions/relu.py
# vanilla-rtrl/functions/sigmoid.py
# vanilla-rtrl/functions/sigmoid_cross_entropy.py
# vanilla-rtrl/functions/softmax.py
# vanilla-rtrl/functions/softmax_cross_entropy.py
# vanilla-rtrl/functions/softplus.py
# vanilla-rtrl/functions/tanh.py
# vanilla-rtrl/gen_data/
# vanilla-rtrl/gen_data/Add_Task.py
# vanilla-rtrl/gen_data/Binary_Addition_Task.py
# vanilla-rtrl/gen_data/Context_Dependent_Integration_Task.py
# vanilla-rtrl/gen_data/Cts_Integration_Task.py
# vanilla-rtrl/gen_data/Delay_Nonmatch_Task.py
# vanilla-rtrl/gen_data/Discrete_Integration_Task.py
# vanilla-rtrl/gen_data/Embedded_Inputs_Task.py
# vanilla-rtrl/gen_data/Fixed_Point_Transition_Task.py
# vanilla-rtrl/gen_data/Flip_Flop_Task.py
# vanilla-rtrl/gen_data/Mimic_RNN.py
# vanilla-rtrl/gen_data/Multi_Task.py
# vanilla-rtrl/gen_data/Sensorimotor_Mapping.py
# vanilla-rtrl/gen_data/Sequential_MNIST.py
# vanilla-rtrl/gen_data/Sine_Wave.py
# vanilla-rtrl/gen_data/Task.py
# vanilla-rtrl/gen_data/__init__.py
# vanilla-rtrl/gen_data/gen_data_utils.py
# vanilla-rtrl/learning_algorithms/
# vanilla-rtrl/learning_algorithms/DNI.py
# vanilla-rtrl/learning_algorithms/Efficient_BPTT.py
# vanilla-rtrl/learning_algorithms/Future_BPTT.py
# vanilla-rtrl/learning_algorithms/KF_RTRL.py
# vanilla-rtrl/learning_algorithms/KeRNL.py
# vanilla-rtrl/learning_algorithms/Learning_Algorithm.py
# vanilla-rtrl/learning_algorithms/List_of_Gradients.py
# vanilla-rtrl/learning_algorithms/Miconi_REINFORCE.py
# vanilla-rtrl/learning_algorithms/Only_Output_Weights.py
# vanilla-rtrl/learning_algorithms/REINFORCE.py
# vanilla-rtrl/learning_algorithms/RFLO.py
# vanilla-rtrl/learning_algorithms/RTRL.py
# vanilla-rtrl/learning_algorithms/Random_Noise_Gradients.py
# vanilla-rtrl/learning_algorithms/Reverse_KF_RTRL.py
# vanilla-rtrl/learning_algorithms/Stochastic_Algorithm.py
# vanilla-rtrl/learning_algorithms/UORO.py
# vanilla-rtrl/learning_algorithms/__init__.py
# vanilla-rtrl/learning_algorithms/tmp.py
# vanilla-rtrl/optimizers/
# vanilla-rtrl/optimizers/Adam.py
# vanilla-rtrl/optimizers/Optimizer.py
# vanilla-rtrl/optimizers/SGD_Momentum.py
# vanilla-rtrl/optimizers/Stochastic_Gradient_Descent.py
# vanilla-rtrl/optimizers/__init__.py
# vanilla-rtrl/plotting/
# vanilla-rtrl/plotting/State_Space_Analysis.py
# vanilla-rtrl/plotting/__init__.py
# vanilla-rtrl/plotting/checkpoint_plots.py
# vanilla-rtrl/plotting/misc.py
# vanilla-rtrl/test/
# vanilla-rtrl/test/__init__.py
# vanilla-rtrl/test/test_gen_data.py
# vanilla-rtrl/test/test_learning_algorithms.py
# vanilla-rtrl/test/test_network.py
# vanilla-rtrl/test/test_optimizers.py
# vanilla-rtrl/test/test_utils.py
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/__init__.py
# vanilla-rtrl/torch_tools/numpy_utils.py
# vanilla-rtrl/torch_tools/torch_rnn.py
# vanilla-rtrl/torch_tools/train.py
# vanilla-rtrl/torch_tools/train_DNI.py
# vanilla-rtrl/utils/
# vanilla-rtrl/utils/__init__.py
# vanilla-rtrl/utils/mathematical_tools.py
# vanilla-rtrl/utils/programming_tools.py
# vanilla-rtrl/wrappers/
# vanilla-rtrl/wrappers/__init__.py
# vanilla-rtrl/wrappers/analyze_individual_checkpoint.py
# vanilla-rtrl/wrappers/analyze_training_run.py
# vanilla-rtrl/wrappers/compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_compare_analyzed_checkpoints.py
# vanilla-rtrl/wrappers/cross_topological_analysis.py
# vanilla-rtrl/wrappers/get_default_args.py
# vanilla-rtrl/wrappers/topological_analysis.py
#
# sent 450,035 bytes  received 2,351 bytes  904,772.00 bytes/sec
# total size is 441,424  speedup is 0.98
# rm: cannot remove ‘/home/om2382/learning-dynamics/results/PNAS_Paper/cross_compare_RFLO_CDM_b200_50_examples_ctx0/result_*’: No such file or directory
# sending incremental file list
# vanilla-rtrl/.idea/
# vanilla-rtrl/.idea/workspace.xml
# vanilla-rtrl/torch_tools/
# vanilla-rtrl/torch_tools/train.py
#
# sent 11,126 bytes  received 82 bytes  22,416.00 bytes/sec
# total size is 441,424  speedup is 39.38

# %%
# !squeue -u om2382
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#      1128716_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128715_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128714_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128713_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128712_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128711_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128710_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128709_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128708_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128707_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128705_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128704_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128703_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128702_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128701_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128700_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128699_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128698_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128697_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128696_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128695_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128694_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128693_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128691_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128690_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128689_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128688_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128687_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128686_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128685_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128683_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128682_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128681_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128680_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128679_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128673_[2-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Resources)
#   1128720_[1-1000] lkumar,bu cross_co   om2382 PD       0:00      1 (Dependency)
#      1128719_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128718_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#      1128717_[1-4] lkumar,bu analyze_   om2382 PD       0:00      1 (Priority)
#          1128674_1     burst analyze_   om2382  R       7:11      1 ax10
#          1128674_2     burst analyze_   om2382  R       7:11      1 ax10
#          1128674_3     burst analyze_   om2382  R       7:11      1 ax11
#          1128674_4     burst analyze_   om2382  R       7:11      1 ax11
#          1128665_1     burst analyze_   om2382  R       7:14      1 ax08
#          1128666_1     burst analyze_   om2382  R       7:14      1 ax09
#          1128665_2     burst analyze_   om2382  R       7:14      1 ax09
#          1128665_3     burst analyze_   om2382  R       7:14      1 ax09
#          1128665_4     burst analyze_   om2382  R       7:14      1 ax09
#          1128666_2     burst analyze_   om2382  R       7:14      1 ax09
#          1128666_3     burst analyze_   om2382  R       7:14      1 ax10
#          1128666_4     burst analyze_   om2382  R       7:14      1 ax10
#          1128657_1     burst analyze_   om2382  R       7:17      1 ax17
#          1128658_1     burst analyze_   om2382  R       7:17      1 ax07
#          1128657_2     burst analyze_   om2382  R       7:17      1 ax18
#          1128657_3     burst analyze_   om2382  R       7:17      1 ax19
#          1128657_4     burst analyze_   om2382  R       7:17      1 ax07
#          1128658_2     burst analyze_   om2382  R       7:17      1 ax07
#          1128658_3     burst analyze_   om2382  R       7:17      1 ax07
#          1128658_4     burst analyze_   om2382  R       7:17      1 ax07
#          1128645_1     burst analyze_   om2382  R       7:20      1 ax13
#          1128646_1     burst analyze_   om2382  R       7:20      1 ax13
#          1128647_1     burst analyze_   om2382  R       7:20      1 ax17
#          1128645_2     burst analyze_   om2382  R       7:20      1 ax13
#          1128645_3     burst analyze_   om2382  R       7:20      1 ax13
#          1128645_4     burst analyze_   om2382  R       7:20      1 ax13
#          1128646_2     burst analyze_   om2382  R       7:20      1 ax13
#          1128646_3     burst analyze_   om2382  R       7:20      1 ax17
#          1128646_4     burst analyze_   om2382  R       7:20      1 ax17
#          1128647_2     burst analyze_   om2382  R       7:20      1 ax17
#          1128647_3     burst analyze_   om2382  R       7:20      1 ax17
#          1128647_4     burst analyze_   om2382  R       7:20      1 ax17
#          1128637_1    lkumar analyze_   om2382  R       7:23      1 ax15
#          1128638_1    lkumar analyze_   om2382  R       7:23      1 ax16
#          1128637_2    lkumar analyze_   om2382  R       7:23      1 ax16
#          1128637_3    lkumar analyze_   om2382  R       7:23      1 ax16
#          1128637_4    lkumar analyze_   om2382  R       7:23      1 ax16
#          1128638_2     burst analyze_   om2382  R       7:23      1 ax02
#          1128638_3     burst analyze_   om2382  R       7:23      1 ax02
#          1128638_4     burst analyze_   om2382  R       7:23      1 ax02
#          1128633_1    lkumar analyze_   om2382  R       7:26      1 ax14
#          1128633_2    lkumar analyze_   om2382  R       7:26      1 ax15
#          1128633_3    lkumar analyze_   om2382  R       7:26      1 ax15
#          1128633_4    lkumar analyze_   om2382  R       7:26      1 ax15
#            1128523    lkumar  jupyter   om2382  R      31:00      1 ax14
#          1128673_1     burst analyze_   om2382  R       7:11      1 ax11

# %%
# !ls saved_runs/

# %%
root_name = 'RFLO_50_examples_ctx0'
signal_dicts, result = unpack_cross_compare_result(root_name, checkpoint_stats={'test_loss': get_checkpoint_loss,
                                                                                'n_nodes': get_checkpoint_n_stable_FPs,
                                                                                'discriminant': get_checkpoint_cubic_discriminant,
                                                                                'lengths': get_checkpoint_maximum_cluster_distances},
                                                   results_subdir='PNAS_Paper',
                                                   multi_job_comp=True)

# %%
root_name = 'length_test_loss'
signal_dicts_0, result_0 = unpack_cross_compare_result(root_name, checkpoint_stats={'test_loss': get_checkpoint_loss,
                                                                                   'n_nodes': get_checkpoint_n_stable_FPs,
                                                                                   'discriminant': get_checkpoint_cubic_discriminant,
                                                                                   'lengths': get_checkpoint_maximum_cluster_distances},
                                                       results_subdir='misc',
                                                       multi_job_comp=True)

# %%
# !rm ../results/misc/cross_compare_length_testloss_lr/result_combined

# %%
root_name = 'three_geo_algs'
signal_geo_dicts, geo_result = unpack_cross_compare_result(root_name,
                                                           results_subdir='PNAS_Paper',
                                                           multi_job_comp=True)

# %%
M = result['rec_weight_distances']
M = M + M.T
plt.figure(figsize=(11, 11))
plt.imshow(M)

# %%
checkpoints['checkpoint_0'].keys()

# %%
for key in signal_dicts.keys():
    plt.plot(np.log10(signal_dicts[key]['test_loss']), color='C7')

# %%
root_name = 'length_testloss_lr'
results_dir = '/home/om2382/learning-dynamics/results/misc'
analysis_jobs = [j for j in os.listdir(results_dir) if root_name in j and 'analyze' in j]
checkpoints_dicts_0 = {}
for job_name in analysis_jobs:
    indices_0, checkpoints_0 = unpack_analysis_results(os.path.join(results_dir, job_name))
    checkpoints_dicts_0[job_name] = {'indices': indices_0,
                                     'checkpoints': checkpoints_0}

# %%
root_name = 'length_testloss_ctx1'
results_dir = '/home/om2382/learning-dynamics/results/misc'
analysis_jobs = [j for j in os.listdir(results_dir) if root_name in j and 'analyze' in j]
checkpoints_dicts_1 = {}
for job_name in analysis_jobs:
    indices_1, checkpoints_1 = unpack_analysis_results(os.path.join(results_dir, job_name))
    checkpoints_dicts_1[job_name] = {'indices': indices_1,
                                     'checkpoints': checkpoints_1}

# %%
signal_keys = [k for k in signal_dicts.keys()]
signal_dicts_list = [signal_dicts[k] for k in signal_keys]
fig = plot_multiple_signals(signal_dicts_list, key_restriction=None, alpha=0.2)

# %%
signal_keys = [k for k in signal_dicts_0.keys()]
signal_dicts_list = [signal_dicts_0[k] for k in signal_keys]
fig = plot_multiple_signals(signal_dicts_list, key_restriction=None, alpha=0.2)

# %%
fig, ax = plt.subplots(4, 5)
for i_key, key in enumerate(signal_dicts):
    ax[2*(i_key//5), i_key%5].plot(np.log10(signal_dicts[key]['test_loss']), color='k')
    ax[2*(i_key//5), i_key%5].axis('off')
    ax[2*(i_key//5) + 1, i_key%5].plot(signal_dicts[key]['lengths'], color='C3')
    ax[2*(i_key//5) + 1, i_key%5].axis('off')

# %%
fig, ax = plt.subplots(2, 10, figsize=(16, 4))
for i_key, key in enumerate(signal_dicts):
    ax[0, i_key].plot(np.log10(signal_dicts[key]['test_loss']), color='k')
    ax[0, i_key].axis('off')
    ax[1, i_key].plot(signal_dicts[key]['lengths'], color='C3')
    ax[1, i_key].axis('off')
    ax[0, i_key].set_ylim([-3, -2])

# %%
fig, ax = plt.subplots(4, 10, figsize=(16, 8))
for i_key, key in enumerate(signal_dicts):
    ax[0, i_key].plot(np.log10(signal_dicts[key]['test_loss']), color='k')
    ax[0, i_key].axis('off')
    ax[1, i_key].plot(signal_dicts[key]['lengths'], color='C3')
    ax[1, i_key].axis('off')
for i_key, key in enumerate(signal_dicts_0):
    ax[2, i_key].plot(np.log10(signal_dicts_0[key]['test_loss']), color='k')
    ax[2, i_key].axis('off')
    ax[3, i_key].plot(signal_dicts_0[key]['lengths'], color='C3')
    ax[3, i_key].axis('off')

# %%
fig, ax = plt.subplots(10, 2, figsize=(8, 20))
for i_seed in range(10):
    for i_lr, lr in enumerate(['0,003', '0,01']):
        key = 'analyze_length_testloss_lr_seed={}_lr={}'.format(i_seed, lr)
        ax[i_seed, i_lr].plot(10 *(np.log10(signal_dicts[key]['test_loss']) + 2))
        ax[i_seed, i_lr].plot(signal_dicts[key]['lengths'])

# %%
i_cp = 900
cp_0 = checkpoints_dicts_0['analyze_length_test_loss_seed=0']['checkpoints']['checkpoint_{}'.format(i_cp)]
cp_1 = checkpoints_dicts_1['analyze_length_testloss_ctx1_seed=0']['checkpoints']['checkpoint_{}'.format(i_cp)]

# %%
task = Context_Dependent_Decision_Task(T_trial=100, input_var=0.1, report_cue=True)
data = task.gen_data(0, 1000)
colors = ['#0000FF', '#D62728']
col1 = '#FF0000'
col2 = '#0000FF'
col3 = '#00FF00'
col4 = '#FFFF00'
probe_colors = linearly_interpolate_colors(col1, col2, 10) + linearly_interpolate_colors(col3, col4, 10)
ssa = State_Space_Analysis(cp_0, data, n_PCs=2)
ssa = plot_checkpoint_results(cp_0, data, ssa,
                              plot_fixed_points=True,
                              plot_cluster_means=True,
                              plot_graph_structure=False,
                              plot_test_points=False,
                              n_test_samples=None,
                              T_per_sample=100,
                              test_alpha=1,
                              plot_probe=True,
                              n_probes=20,
                              probe_colors=probe_colors,
                              eig_norm_color=True,
                              graph_key='adjmat_input_1')
W_in_ = cp_0['rnn'].W_in[:,0]
W_out_ = cp_0['rnn'].W_out[0]
w_in = ssa.transform(W_in_)
w_in = w_in / norm(w_in)
w_out = ssa.transform(W_out_)
w_out = w_out / norm(w_out)
#plt.title(key + ', in-out-alignment = {}'.format(normalized_dot_product(W_in_, W_out_)))
#plt.title(key)
if True:
    #ssa.ax.plot([-w_in[0], w_in[0]],
    #            [-w_in[1], w_in[1]], color='k', linewidth=2)
    ssa.ax.plot([-w_out[0], w_out[0]],
                [-w_out[1], w_out[1]], color='g', linewidth=2)
    window_size = 1.2

# %%
task = Context_Dependent_Decision_Task(T_trial=100, input_var=0.1, report_cue=True)
data = task.gen_data(0, 1000)
colors = ['#0000FF', '#D62728']
col1 = '#FF0000'
col2 = '#0000FF'
col3 = '#00FF00'
col4 = '#FFFF00'
probe_colors = linearly_interpolate_colors(col1, col2, 10) + linearly_interpolate_colors(col3, col4, 10)
ssa = State_Space_Analysis(cp_1, data, n_PCs=2)
ssa = plot_checkpoint_results(cp_1, data, ssa,
                              plot_fixed_points=True,
                              plot_cluster_means=True,
                              plot_graph_structure=False,
                              plot_test_points=False,
                              n_test_samples=None,
                              T_per_sample=100,
                              test_alpha=1,
                              plot_probe=True,
                              n_probes=20,
                              probe_colors=probe_colors,
                              eig_norm_color=True,
                              graph_key='adjmat_input_1')
W_in_ = cp_1['rnn'].W_in[:,0]
W_out_ = cp_1['rnn'].W_out[0]
w_in = ssa.transform(W_in_)
w_in = w_in / norm(w_in)
w_out = ssa.transform(W_out_)
w_out = w_out / norm(w_out)
#plt.title(key + ', in-out-alignment = {}'.format(normalized_dot_product(W_in_, W_out_)))
#plt.title(key)
if True:
    #ssa.ax.plot([-w_in[0], w_in[0]],
    #            [-w_in[1], w_in[1]], color='k', linewidth=2)
    ssa.ax.plot([-w_out[0], w_out[0]],
                [-w_out[1], w_out[1]], color='g', linewidth=2)
    window_size = 1.2

# %%
np.std(cp_1['fixed_points'][np.where(cp_1['cluster_labels'] == 0)], axis=0).mean()

# %%
np.std(cp_0['fixed_points'][np.where(cp_0['cluster_labels'] == 1)], axis=0).mean()

# %%
M = distance.pdist(cp_0['fixed_points'][np.where(cp_0['cluster_labels'] == 1)], 'euclidean')

# %%
M = distance.squareform(M)

# %%
np.where(M == np.max(M))

# %%
r_2 = cp_0['fixed_points'][np.where(cp_0['cluster_labels'] == 1)][57]
W_rec = cp_0['rnn'].W_rec.copy()
W_in = cp_0['rnn'].W_in.copy()
b_rec = cp_0['rnn'].b_rec.copy()
c_2 = np.eye(5)[2]
c_1 = np.eye(5)[3]
Delta_c = c_2 - c_1
h_2 = W_rec.dot(r_2) + W_in.dot(c_2) + b_rec
Delta_r = np.linalg.inv(np.eye(32) - np.diag((1 - np.tanh(h_2))**2).dot(W_rec)).dot(np.diag((1 - np.tanh(h_2))**2)).dot(W_in.dot(Delta_c))
r_1 = r_2 - Delta_r

# %%
r_2_ = cp_0['fixed_points'][np.where(cp_0['cluster_labels'] == 1)][200]
W_rec = cp_0['rnn'].W_rec.copy()
W_in = cp_0['rnn'].W_in.copy()
b_rec = cp_0['rnn'].b_rec.copy()
c_2 = np.eye(5)[2]
c_1 = np.eye(5)[3]
Delta_c = c_2 - c_1
h_2 = W_rec.dot(r_2_) + W_in.dot(c_2) + b_rec
Delta_r = np.linalg.inv(np.eye(32) - np.diag((1 - np.tanh(h_2))**2).dot(W_rec)).dot(np.diag((1 - np.tanh(h_2))**2)).dot(W_in.dot(Delta_c))
r_1_ = r_2 - Delta_r

# %%
M1 = distance.pdist(cp_0['fixed_points'][np.where(cp_0['cluster_labels'] == 0)], 'euclidean')
M1 = distance.squareform(M1)
np.where(M1 == np.max(M1))

# %%
r_1_real = cp_1['fixed_points'][np.where(cp_1['cluster_labels'] == 0)][82]

# %%
r_1_real_ = cp_1['fixed_points'][np.where(cp_1['cluster_labels'] == 0)][13]

# %%
plt.plot(r_1)
plt.plot(r_1_)
plt.plot(r_1_real)
plt.plot(r_1_real_)

# %%
plt.plot(signal_dicts_0['analyze_length_test_loss_seed=0']['lengths'])

# %%
root_name = 'length_testloss_lr'
results_dir = '/home/om2382/learning-dynamics/results/misc'
analysis_jobs = [j for j in os.listdir(results_dir) if root_name in j and 'analyze' in j]
checkpoints_dicts = {}
for job_name in analysis_jobs:
    indices, checkpoints = unpack_analysis_results(os.path.join(results_dir, job_name))
    checkpoints_dicts[job_name] = {'indices': indices,
                                     'checkpoints': checkpoints}

# %%
fig, ax = plt.subplots(4, 10, figsize=(24, 6))
for i_seed in range(10):
    for i_lr, lr in enumerate(['01', '003']):
        test_loss = []
        lengths = []
        key = 'analyze_length_testloss_lr_seed={}_lr=0,{}'.format(i_seed, lr)
        CPs = checkpoints_dicts[key]['checkpoints']
        for i_cp in range(0, 1000, 100):
            test_loss.append(np.log10(get_checkpoint_loss))
            lengths.append(get_checkpoint_maximum_cluster_distances)
        ax[2*i_lr, i_seed].plot(test_loss, 'k')
        ax[2*i_lr + 1, i_seed].plot(lengths, 'C3')
